# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from keras.preprocessing.image import load_img
from tensorflow.keras.optimizers import RMSprop

# %%
img=image.load_img("/home/user/Desktop/interdiciplinary/ASL/A/A_1.jpg")

# %%
plt.imshow(img)

# %%
cv2.imread("/home/user/Desktop/interdiciplinary/ASL/A/A_1.jpg").shape
# Out:
# (200, 200, 3)

# %%
train = ImageDataGenerator(rescale= 1/255)
validation = ImageDataGenerator(rescale= 1/255)

# %%
train_dataset = train.flow_from_directory('/home/user/Desktop/interdiciplinary/ASL/asl_alphabet_train',
                                          target_size=(200,200),
                                          batch_size = 3,
                                          class_mode = 'categorical')
validation_dataset = validation.flow_from_directory('/home/user/Desktop/interdiciplinary/ASL/asl_alphabet_test',
                                          target_size=(200,200),
                                          batch_size = 3,
                                          class_mode = 'categorical')
# Out:
# Found 87000 images belonging to 29 classes.
# Found 0 images belonging to 0 classes.

# %%
train_dataset.class_indices
# Out:
# {'A': 0,
#  'B': 1,
#  'C': 2,
#  'D': 3,
#  'E': 4,
#  'F': 5,
#  'G': 6,
#  'H': 7,
#  'I': 8,
#  'J': 9,
#  'K': 10,
#  'L': 11,
#  'M': 12,
#  'N': 13,
#  'O': 14,
#  'P': 15,
#  'Q': 16,
#  'R': 17,
#  'S': 18,
#  'T': 19,
#  'U': 20,
#  'V': 21,
#  'W': 22,
#  'X': 23,
#  'Y': 24,
#  'Z': 25,
#  'del': 26,
#  'nothing': 27,
#  'space': 28}

# %%
train_dataset.classes
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28], dtype=int32)

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3), activation = 'relu', input_shape = (200,200,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   
                                    tf.keras.layers.Conv2D(32,(3,3), activation = 'relu', input_shape = (200,200,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   
                                    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu', input_shape = (200,200,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   
                                    tf.keras.layers.Flatten(),
                                    
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                    
                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                   ])

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer = RMSprop(learning_rate=0.001),
             metrics=['accuracy'])

# %%
model_fit=model.fit(train_dataset, steps_per_epoch = 3, epochs=10, validation_data = validation_dataset)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 3s 301ms/step - loss: 0.5071 - accuracy: 0.6552
# Epoch 2/10
# 3/3 [==============================] - 1s 343ms/step - loss: 0.2653 - accuracy: 0.9655
# Epoch 3/10
# 3/3 [==============================] - 1s 280ms/step - loss: 0.1674 - accuracy: 0.9655
# Epoch 4/10
# 3/3 [==============================] - 1s 362ms/step - loss: 0.1728 - accuracy: 0.9655
# Epoch 5/10
# 3/3 [==============================] - 1s 268ms/step - loss: 0.1880 - accuracy: 0.9655
# Epoch 6/10
# 3/3 [==============================] - 1s 277ms/step - loss: 0.1539 - accuracy: 0.9655
# Epoch 7/10
# 3/3 [==============================] - 1s 325ms/step - loss: 0.1617 - accuracy: 0.9655
# Epoch 8/10
# 3/3 [==============================] - 1s 269ms/step - loss: 0.1709 - accuracy: 0.9655
# Epoch 9/10
# 3/3 [==============================] - 1s 268ms/step - loss: 0.1616 - accuracy: 0.9655
# Epoch 10/10
# ...

# %%
dir_path = "/home/user/Desktop/interdiciplinary/ASL/asl_alphabet_test"
for i in os.listdir(dir_path):
    img= image.load_img(dir_path + '//' + i, target_size=(200,200))
    plt.imshow(img)
    plt.show()
    
    X=image.img_to_array(img)
    X=np.expand_dims(X,axis =0)
    images = np.vstack([X])
    val = model.predict(images)
    if val ==0:
        print("A")
    if val ==1:
        print("B")
    if val ==2:
        print("C")
    if val ==3:
        print("D")
    if val ==4:
        print("E")
    if val ==5:
        print("F")
    if val ==6:
        print("G")
    if val ==7:
        print("H")
    if val ==8:
        print("I")
    if val ==9:
        print("J")
    if val ==10:
        print("K")
    if val ==11:
        print("L")
    if val ==12:
        print("M")
    if val ==13:
        print("N")
    if val ==14:
        print("O")
    if val ==15:
        print("P")
    if val ==16:
        print("Q")
    if val ==17:
        print("R")
    if val ==18:
        print("S")
    if val ==19:
        print("T")
    if val ==20:
        print("U")
    if val ==21:
        print("V")
    if val ==22:
        print("W")
    if val ==23:
        print("X")
    if val ==24:
        print("Y")
    if val ==25:
        print("Z")
        
    else:
        print("Heyat qisa deymez qiza")
# Out:
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
# A
# Heyat qisa deymez qiza
